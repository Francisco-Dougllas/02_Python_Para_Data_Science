# %% [markdown]
# <a href="https://colab.research.google.com/github/Francisco-Dougllas/02_Python_Para_Data_Science/blob/main/01_Python_Para_Data_Science_%26_Data_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Criando e Manipulando Dataframes

# %% [markdown]
# ## Criando um DataFrame

# %%
# Importando as bibliotecas necessarias
import pandas as pd
import numpy as np

# %%
# Criando uma Serie de Dados
series = pd.Series([17, 8, 4, np.nan, 12, 18 ])
series
# Out:
# 0    17.0
# 1     8.0
# 2     4.0
# 3     NaN
# 4    12.0
# 5    18.0
# dtype: float64

# %%
# Tipo da Serie
type(series)
# Out:
# pandas.core.series.Series

# %%
# Criando Datas
data = pd.date_range('20220101', periods=12)
data
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10', '2022-01-11', '2022-01-12'],
#               dtype='datetime64[ns]', freq='D')

# %%
# Criando Datas 2
data = pd.date_range('20220101', periods=250, freq='D')
data
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10',
#                ...
#                '2022-08-29', '2022-08-30', '2022-08-31', '2022-09-01',
#                '2022-09-02', '2022-09-03', '2022-09-04', '2022-09-05',
#                '2022-09-06', '2022-09-07'],
#               dtype='datetime64[ns]', length=250, freq='D')

# %%
# Tipo de Datas
type(data)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
# Criando um DataFrame
df = pd.DataFrame(np.random.randn(250, 8), index=data, columns=list('ABCDEFGH'))
df.head()
# Out:
#                    A         B         C         D         E         F  \
# 2022-01-01 -0.620602 -0.884041  0.110451 -1.001433  1.170141  0.023539
# 2022-01-02 -0.728748  1.322367  0.259804 -0.946404 -0.997068  0.331670
# 2022-01-03 -0.738230  0.976524 -1.671825  1.209692  0.029753 -0.674233
# 2022-01-04 -1.959976  1.578978  2.242348  0.679530  0.503983  0.625734
# 2022-01-05  1.444700 -0.191269 -2.331830 -0.451177 -0.677521  0.415679
#
#                    G         H
# 2022-01-01  0.880825 -0.449286
# 2022-01-02 -0.605019  1.699938
# 2022-01-03  0.425159  0.303503
# 2022-01-04  0.074078 -0.393585
# 2022-01-05 -1.177938 -0.570872

# %%
# Visualizando as Colunas
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'], dtype='object')

# %%
# Tipo do df
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Gerando Valores Aleatorios
np.random.randn(12, 6)
# Out:
# array([[-0.87000259,  0.63770239, -0.25244728, -0.18484167,  0.23582488,
#         -1.86980809],
#        [ 0.25665818, -0.88651783, -0.2435415 , -0.21214297, -0.36632317,
#          0.49227621],
#        [ 0.10645387,  0.96821129, -0.37024377, -0.28871728, -0.95567733,
#         -0.84411029],
#        [-1.03953409,  1.61358617, -0.02281895,  0.10286355, -0.03044484,
#         -2.29799642],
#        [ 0.08157952, -0.37614711, -1.58395464, -0.4701202 ,  0.03801878,
#          1.34804339],
#        [ 0.44772697,  1.92290983,  2.4198546 , -0.25118247,  0.76503448,
#         -1.98965895],
#        [-0.86781752,  0.4904317 ,  0.71799727, -0.98362239, -0.98339437,
#         -1.15306658],
#        [-0.75045634,  0.55209108, -1.30954795, -1.13427542, -2.33038196,
#         -0.05386343],
#        [ 0.53952107,  0.29171912,  0.40474235, -0.86953903, -0.59110051,
#         -1.20404679],
#        [-0.87729411, -0.24970528,  1.81931706, -0.73943876,  0.37336417,
#          1.05330096],
#        [ 1.59757371, -0.44448175, -0.80220534, -0.17696804, -1.314371  ,
#          1.41221859],
#        [-1.81743429, -1.13813217,  0.17459606,  0.14692844, -0.59302947,
#          0.3926317 ]])

# %%
# Outra Maneira de Criar um DataFrame com Valores Aleatorios

df2 = pd.DataFrame({"A": 7,
                    "B": pd.Timestamp('20190101'),
                    "C": pd.Series(1, index=list(range(4)), dtype='float32'),
                    "D": np.array([3] * 4, dtype='int32'),
                    "E": pd.Categorical(['test', 'train', 'test', 'train']),
                    "F": 'Python'})
df2
# Out:
#    A          B    C  D      E       F
# 0  7 2019-01-01  1.0  3   test  Python
# 1  7 2019-01-01  1.0  3  train  Python
# 2  7 2019-01-01  1.0  3   test  Python
# 3  7 2019-01-01  1.0  3  train  Python

# %% [markdown]
# ### Adicionando Colunas ao DataFrame df

# %%
# Criando o DataFrame
datas = pd.date_range('20220101', periods=300, freq='D')
df = pd.DataFrame(np.random.randn(300, 10), index=datas, columns = list('ABCDEFGHIJ'))
df.head()
# Out:
#                    A         B         C         D         E         F  \
# 2022-01-01 -0.241416 -0.387455  0.862204  0.201126 -1.108971  0.809410
# 2022-01-02 -0.342745 -0.615299 -1.272007  0.606352 -0.273387  0.159152
# 2022-01-03  0.316833  0.326370  0.112486  0.984399  0.375653  0.313334
# 2022-01-04 -0.769314  0.981932 -0.173275 -1.823967 -0.322814 -0.215618
# 2022-01-05 -0.654110 -0.859019 -0.358293 -0.497373 -0.115615 -1.161800
#
#                    G         H         I         J
# 2022-01-01  0.356648  0.026640  0.582457  0.399702
# 2022-01-02  0.250125  0.701725 -0.569611  1.805902
# 2022-01-03  0.125142  1.477431 -0.530412 -0.000576
# 2022-01-04 -0.644478  1.222676 -0.740635  0.993247
# 2022-01-05 -0.764903 -0.748135 -0.388378  0.546430

# %%
# Shape Linhas e Colunas do Dataframe
df.shape
# Out:
# (300, 10)

# %%
# Adicionando uma Nova Coluna com valores de 0 a 300
df['K'] = range(300)
df.head()
# Out:
#                    A         B         C         D         E         F  \
# 2022-01-01 -0.241416 -0.387455  0.862204  0.201126 -1.108971  0.809410
# 2022-01-02 -0.342745 -0.615299 -1.272007  0.606352 -0.273387  0.159152
# 2022-01-03  0.316833  0.326370  0.112486  0.984399  0.375653  0.313334
# 2022-01-04 -0.769314  0.981932 -0.173275 -1.823967 -0.322814 -0.215618
# 2022-01-05 -0.654110 -0.859019 -0.358293 -0.497373 -0.115615 -1.161800
#
#                    G         H         I         J  K
# 2022-01-01  0.356648  0.026640  0.582457  0.399702  0
# 2022-01-02  0.250125  0.701725 -0.569611  1.805902  1
# 2022-01-03  0.125142  1.477431 -0.530412 -0.000576  2
# 2022-01-04 -0.644478  1.222676 -0.740635  0.993247  3
# 2022-01-05 -0.764903 -0.748135 -0.388378  0.546430  4

# %%
# Criando uma Coluna com o Nome produto
df['Produto'] = (df['A'] + df['B']) * df['D']
df.head()
# Out:
#                    A         B         C         D         E         F  \
# 2022-01-01 -0.241416 -0.387455  0.862204  0.201126 -1.108971  0.809410
# 2022-01-02 -0.342745 -0.615299 -1.272007  0.606352 -0.273387  0.159152
# 2022-01-03  0.316833  0.326370  0.112486  0.984399  0.375653  0.313334
# 2022-01-04 -0.769314  0.981932 -0.173275 -1.823967 -0.322814 -0.215618
# 2022-01-05 -0.654110 -0.859019 -0.358293 -0.497373 -0.115615 -1.161800
#
#                    G         H         I         J  K   Produto
# 2022-01-01  0.356648  0.026640  0.582457  0.399702  0 -0.126482
# 2022-01-02  0.250125  0.701725 -0.569611  1.805902  1 -0.580912
# 2022-01-03  0.125142  1.477431 -0.530412 -0.000576  2  0.633169
# 2022-01-04 -0.644478  1.222676 -0.740635  0.993247  3 -0.387809
# 2022-01-05 -0.764903 -0.748135 -0.388378  0.546430  4  0.752590

# %% [markdown]
# ### Visualizando Dados

# %%
# 5 Primeiras Linhas
df.head()
# Out:
#                    A         B         C         D         E         F  \
# 2022-01-01 -0.241416 -0.387455  0.862204  0.201126 -1.108971  0.809410
# 2022-01-02 -0.342745 -0.615299 -1.272007  0.606352 -0.273387  0.159152
# 2022-01-03  0.316833  0.326370  0.112486  0.984399  0.375653  0.313334
# 2022-01-04 -0.769314  0.981932 -0.173275 -1.823967 -0.322814 -0.215618
# 2022-01-05 -0.654110 -0.859019 -0.358293 -0.497373 -0.115615 -1.161800
#
#                    G         H         I         J  K   Produto
# 2022-01-01  0.356648  0.026640  0.582457  0.399702  0 -0.126482
# 2022-01-02  0.250125  0.701725 -0.569611  1.805902  1 -0.580912
# 2022-01-03  0.125142  1.477431 -0.530412 -0.000576  2  0.633169
# 2022-01-04 -0.644478  1.222676 -0.740635  0.993247  3 -0.387809
# 2022-01-05 -0.764903 -0.748135 -0.388378  0.546430  4  0.752590

# %%
# 5 Ultimas Linhas
df.tail()
# Out:
#                    A         B         C         D         E         F  \
# 2022-10-23  1.570881  0.936584 -0.899001  1.486939 -0.654268 -1.207542
# 2022-10-24 -0.937267 -2.051755 -2.054423  1.495819  0.674592  0.535623
# 2022-10-25  1.112826 -0.232326  0.620341  1.059869  0.101444  0.027868
# 2022-10-26 -1.190861  0.097849  1.048519  0.561267  2.873057 -0.312350
# 2022-10-27  0.837252  0.112194 -0.953133 -0.491328 -0.652750 -0.469370
#
#                    G         H         I         J    K   Produto
# 2022-10-23  0.596360  0.833877 -0.112069 -1.290137  295  3.728450
# 2022-10-24  0.216166 -0.483125  0.577629  0.254955  296 -4.471036
# 2022-10-25  0.730084  0.271981 -0.379212  0.111871  297  0.933215
# 2022-10-26 -1.058690 -0.840117 -0.575891 -1.082683  298 -0.613472
# 2022-10-27  0.063461  0.396616  0.076499 -0.578643  299 -0.466489

# %%
# Amostra Aleatoria dos dados
df.sample(7)
# Out:
#                    A         B         C         D         E         F  \
# 2022-02-28  0.501826  0.152427  2.140032 -0.542897  1.836154  1.761834
# 2022-05-16 -0.108320 -1.453349 -0.380022  1.049461  1.049599 -1.368537
# 2022-02-27 -1.707497 -0.132512 -2.450921 -2.511054 -0.641894  0.457059
# 2022-09-28 -0.827891 -0.400501 -0.990867 -0.934807  2.893489 -1.819849
# 2022-07-06  0.809107 -2.395066  1.088177  0.012121  0.641317  1.627074
# 2022-10-08 -0.296462  0.575083 -0.357399  1.323999  0.647244  0.878667
# 2022-03-01 -0.323727  0.581640 -0.107111  0.287953 -0.685018 -0.683155
#
#                    G         H         I         J    K   Produto
# 2022-02-28 -0.595914  0.369367 -1.192355  0.767745   58 -0.355192
# 2022-05-16 -1.684189 -0.774707  0.392682 -2.494292  135 -1.638911
# 2022-02-27  0.482687  0.338239  1.060108  0.039722   57  4.620361
# 2022-09-28  0.172614  1.838484  2.226175  0.180564  270  1.148310
# 2022-07-06 -0.471887  1.355259 -0.924147 -0.795132  186 -0.019224
# 2022-10-08  3.181896 -0.164133  0.405647 -1.573921  280  0.368894
# 2022-03-01 -0.695540  0.067051  0.269242  0.332795   59  0.074267

# %%
# Index dos dados
df.index
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10',
#                ...
#                '2022-10-18', '2022-10-19', '2022-10-20', '2022-10-21',
#                '2022-10-22', '2022-10-23', '2022-10-24', '2022-10-25',
#                '2022-10-26', '2022-10-27'],
#               dtype='datetime64[ns]', length=300, freq='D')

# %%
# Colunas
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'Produto'], dtype='object')

# %%
# Transformando em Uma Matriz do Numpy
df.to_numpy
# Out:
# <bound method DataFrame.to_numpy of                    A         B         C         D         E         F  \
# 2022-01-01 -0.241416 -0.387455  0.862204  0.201126 -1.108971  0.809410
# 2022-01-02 -0.342745 -0.615299 -1.272007  0.606352 -0.273387  0.159152
# 2022-01-03  0.316833  0.326370  0.112486  0.984399  0.375653  0.313334
# 2022-01-04 -0.769314  0.981932 -0.173275 -1.823967 -0.322814 -0.215618
# 2022-01-05 -0.654110 -0.859019 -0.358293 -0.497373 -0.115615 -1.161800
# ...              ...       ...       ...       ...       ...       ...
# 2022-10-23  1.570881  0.936584 -0.899001  1.486939 -0.654268 -1.207542
# 2022-10-24 -0.937267 -2.051755 -2.054423  1.495819  0.674592  0.535623
# 2022-10-25  1.112826 -0.232326  0.620341  1.059869  0.101444  0.027868
# 2022-10-26 -1.190861  0.097849  1.048519  0.561267  2.873057 -0.312350
# 2022-10-27  0.837252  0.112194 -0.953133 -0.491328 -0.652750 -0.469370
#
#                    G         H         I         J    K   Produto
# 2022-01-01  0.356648  0.026640  0.582457  0.399702    0 -0.126482
# 2022-01-02  0.250125  0.701725 -0.569611  1.805902    1 -0.580912
# 2022-01-03  0.125142  1.477431 -0.530412 -0.000576    2  0.633169
# 2022-01-04 -0.644478  1.222676 -0.740635  0.993247    3 -0.387809
# 2022-01-05 -0.764903 -0.748135 -0.388378  0.546430    4  0.752590
# ...              ...       ...       ...       ...  ...       ...
# 2022-10-23  0.596360  0.833877 -0.112069 -1.290137  295  3.728450
# 2022-10-24  0.216166 -0.483125  0.577629  0.254955  296 -4.471036
# 2022-10-25  0.730084  0.271981 -0.379212  0.111871  297  0.933215
# 2022-10-26 -1.058690 -0.840117 -0.575891 -1.082683  298 -0.613472
# 2022-10-27  0.063461  0.396616  0.076499 -0.578643  299 -0.466489
#
# [300 rows x 12 columns]>

# %%
# Obtendo o Transposta dos dados
df.T.head()
# Out:
#    2022-01-01  2022-01-02  2022-01-03  2022-01-04  2022-01-05  2022-01-06  \
# A   -0.241416   -0.342745    0.316833   -0.769314   -0.654110    0.516597
# B   -0.387455   -0.615299    0.326370    0.981932   -0.859019   -0.111870
# C    0.862204   -1.272007    0.112486   -0.173275   -0.358293   -0.169940
# D    0.201126    0.606352    0.984399   -1.823967   -0.497373   -0.859047
# E   -1.108971   -0.273387    0.375653   -0.322814   -0.115615   -0.537704
#
#    2022-01-07  2022-01-08  2022-01-09  2022-01-10  ...  2022-10-18  \
# A    0.471608   -0.770824    0.434305    0.991890  ...    0.852990
# B   -0.651866    0.352035   -0.586240    1.570499  ...   -0.753283
# C    0.055898    0.169112    0.912126    1.728303  ...    0.233907
# D    1.770875    0.823948    2.291714    1.041594  ...    1.267635
# E    0.921336    0.191817   -0.322690   -0.240872  ...    1.241374
#
#    2022-10-19  2022-10-20  2022-10-21  2022-10-22  2022-10-23  2022-10-24  \
# A   -0.667124   -0.503365   -0.062079    0.256660    1.570881   -0.937267
# B    2.223973    1.805124    0.512664   -0.199014    0.936584   -2.051755
# C   -1.143455   -0.085759    0.345816    0.412293   -0.899001   -2.054423
# D   -1.143431   -0.850706   -0.243542   -0.855789    1.486939    1.495819
# E   -1.290087   -0.399229    1.174028   -1.731023   -0.654268    0.674592
#
#    2022-10-25  2022-10-26  2022-10-27
# A    1.112826   -1.190861    0.837252
# B   -0.232326    0.097849    0.112194
# C    0.620341    1.048519   -0.953133
# D    1.059869    0.561267   -0.491328
# E    0.101444    2.873057   -0.652750
#
# [5 rows x 300 columns]

# %% [markdown]
# # Combinando DataFrames
#
# Para Isso sera criado 3 dataframes

# %%
# Criando o DataFrame 1
datas = pd.date_range('20200101', periods=300, freq='D')
df1 = pd.DataFrame(np.random.randn(300, 10), index=datas, columns = list('ABCDEFGHIJ'))
df1.head()
# Out:
#                    A         B         C         D         E         F  \
# 2020-01-01  1.648990  1.396523 -0.864225 -0.315719  1.547830  0.184701
# 2020-01-02  0.330507  0.344368  0.099203  0.305978 -0.281050  1.119243
# 2020-01-03 -1.275643 -0.736017 -0.131115 -0.023972 -0.604407  0.246074
# 2020-01-04  0.152178 -0.281492 -0.471108 -1.568616 -0.265702  0.661561
# 2020-01-05  0.579654  0.528185  0.688085 -0.289042  0.480916 -0.361852
#
#                    G         H         I         J
# 2020-01-01  0.551912  0.465274  1.213617 -1.315941
# 2020-01-02  1.701476  0.223683  0.642237 -0.946725
# 2020-01-03 -0.026019  0.483463 -1.368562 -1.157156
# 2020-01-04  0.937281  0.489924  0.810059 -0.165005
# 2020-01-05  0.103390 -0.398663  1.203929 -2.067660

# %%
# Criando o DataFrame 2
datas = pd.date_range('20210101', periods=300, freq='D')
df2 = pd.DataFrame(np.random.randn(300, 10), index=datas, columns = list('ABCDEFGHIJ'))
df2.head()
# Out:
#                    A         B         C         D         E         F  \
# 2021-01-01  0.186752 -0.134276  0.721816  1.004341 -0.255454  0.110017
# 2021-01-02  0.003117 -0.182390  0.612862  0.312800  0.988963 -0.687260
# 2021-01-03 -0.529199  0.731731 -1.221858 -0.513324  0.374927 -0.916226
# 2021-01-04  2.332009 -0.754733  0.916260  0.567419  0.296503 -0.517076
# 2021-01-05 -1.317925  0.304651  0.169310  0.006588 -0.104622  0.826871
#
#                    G         H         I         J
# 2021-01-01 -0.525493  0.191569 -2.056157  0.836757
# 2021-01-02  1.384323 -0.304808  2.176619 -0.731563
# 2021-01-03  0.776934  0.922461  0.143156 -0.080159
# 2021-01-04  1.054942 -1.192336 -0.017205  0.934854
# 2021-01-05  1.559803  1.624722 -0.965571  0.818116

# %%
# Criando o DataFrame
datas = pd.date_range('20220101', periods=300, freq='D')
df3 = pd.DataFrame(np.random.randn(300, 10), index=datas, columns = list('ABCDEFGHIJ'))
df3.head()
# Out:
#                    A         B         C         D         E         F  \
# 2022-01-01  0.520464 -0.813841 -0.251572  0.135994 -0.282827 -0.702248
# 2022-01-02 -0.119098 -1.054948 -1.331311 -0.483698  0.852818  0.092187
# 2022-01-03  1.628006 -0.815280  0.150884  0.073129  0.459429  0.348729
# 2022-01-04  1.066214 -2.499977  0.819622  0.805595 -0.427055 -0.780485
# 2022-01-05 -0.115672  1.631926  0.193380 -1.202152 -0.266095 -0.677003
#
#                    G         H         I         J
# 2022-01-01  0.547692 -0.964915  2.876649 -0.615010
# 2022-01-02  2.410484 -2.109551  0.307817  1.028815
# 2022-01-03 -0.233887 -1.426068  0.593008 -0.543273
# 2022-01-04  0.381768 -0.773279 -0.127585  0.636191
# 2022-01-05 -1.699881  0.887734  0.080535 -0.451164

# %%
# Junção dos DataFrames Concatenação
# A Forma mais correta de se fazer e

frames = pd.concat([df1, df2, df3])
frames.head()
# Out:
#                    A         B         C         D         E         F  \
# 2020-01-01  1.648990  1.396523 -0.864225 -0.315719  1.547830  0.184701
# 2020-01-02  0.330507  0.344368  0.099203  0.305978 -0.281050  1.119243
# 2020-01-03 -1.275643 -0.736017 -0.131115 -0.023972 -0.604407  0.246074
# 2020-01-04  0.152178 -0.281492 -0.471108 -1.568616 -0.265702  0.661561
# 2020-01-05  0.579654  0.528185  0.688085 -0.289042  0.480916 -0.361852
#
#                    G         H         I         J
# 2020-01-01  0.551912  0.465274  1.213617 -1.315941
# 2020-01-02  1.701476  0.223683  0.642237 -0.946725
# 2020-01-03 -0.026019  0.483463 -1.368562 -1.157156
# 2020-01-04  0.937281  0.489924  0.810059 -0.165005
# 2020-01-05  0.103390 -0.398663  1.203929 -2.067660

# %%
# Shape
frames.shape
# Out:
# (900, 10)

# %%
# Concatenando os Dataframes e Identificando cada pela chave keys
dfs = pd.concat([df1, df2, df3], keys=['Dados1', 'Dados2', 'Dados3'])
dfs.head()
# Out:
#                           A         B         C         D         E         F  \
# Dados1 2020-01-01  1.648990  1.396523 -0.864225 -0.315719  1.547830  0.184701
#        2020-01-02  0.330507  0.344368  0.099203  0.305978 -0.281050  1.119243
#        2020-01-03 -1.275643 -0.736017 -0.131115 -0.023972 -0.604407  0.246074
#        2020-01-04  0.152178 -0.281492 -0.471108 -1.568616 -0.265702  0.661561
#        2020-01-05  0.579654  0.528185  0.688085 -0.289042  0.480916 -0.361852
#
#                           G         H         I         J
# Dados1 2020-01-01  0.551912  0.465274  1.213617 -1.315941
#        2020-01-02  1.701476  0.223683  0.642237 -0.946725
#        2020-01-03 -0.026019  0.483463 -1.368562 -1.157156
#        2020-01-04  0.937281  0.489924  0.810059 -0.165005
#        2020-01-05  0.103390 -0.398663  1.203929 -2.067660

# %%
# Usando o Loc para visualiza os valores do df2
dfs.loc['Dados2'].head()
# Out:
#                    A         B         C         D         E         F  \
# 2021-01-01  0.186752 -0.134276  0.721816  1.004341 -0.255454  0.110017
# 2021-01-02  0.003117 -0.182390  0.612862  0.312800  0.988963 -0.687260
# 2021-01-03 -0.529199  0.731731 -1.221858 -0.513324  0.374927 -0.916226
# 2021-01-04  2.332009 -0.754733  0.916260  0.567419  0.296503 -0.517076
# 2021-01-05 -1.317925  0.304651  0.169310  0.006588 -0.104622  0.826871
#
#                    G         H         I         J
# 2021-01-01 -0.525493  0.191569 -2.056157  0.836757
# 2021-01-02  1.384323 -0.304808  2.176619 -0.731563
# 2021-01-03  0.776934  0.922461  0.143156 -0.080159
# 2021-01-04  1.054942 -1.192336 -0.017205  0.934854
# 2021-01-05  1.559803  1.624722 -0.965571  0.818116

# %% [markdown]
# ## Merge e GroupBy

# %% [markdown]
# Para representação do Merge, usaremos Dados Ficticios de 2 Lojas

# %%
# Cadastro da Loja A

cadastro_a = {'Id': ['AA2930', 'BB4563', 'CC2139', 'DE2521', 'GT3462', 'HH1158'],
            "Nome": ['Victor', 'Amanda', 'Bruna', 'Carlos', 'Ricardo', 'Maria'],
            "Idade": [20, 35, 40, 54, 30, 27],
            "CEP": ['00092-029', '11111-111', '00000-999', '22222-888', '88888-111', '77777-666']}

cadastro_a = pd.DataFrame(cadastro_a, columns=['Id', 'Nome', 'Idade', 'CEP'])
cadastro_a
# Out:
#        Id     Nome  Idade        CEP
# 0  AA2930   Victor     20  00092-029
# 1  BB4563   Amanda     35  11111-111
# 2  CC2139    Bruna     40  00000-999
# 3  DE2521   Carlos     54  22222-888
# 4  GT3462  Ricardo     30  88888-111
# 5  HH1158    Maria     27  77777-666

# %%
# Cadastro da Loja B

cadastro_b = {'Id': ['CC9999', 'EF4488', 'DD9999', 'GT3462', 'HH1158'],
            "Nome": ['Marcos', 'Patricia', 'Ericka', 'Ricardo', 'Maria'],
            "Idade": [19, 30, 22, 30, 27],
            "CEP": ['00092-029', '11111-111', '11111-888', '88888-111', '77777-666']}

cadastro_b = pd.DataFrame(cadastro_b, columns=['Id', 'Nome', 'Idade', 'CEP'])
cadastro_b
# Out:
#        Id      Nome  Idade        CEP
# 0  CC9999    Marcos     19  00092-029
# 1  EF4488  Patricia     30  11111-111
# 2  DD9999    Ericka     22  11111-888
# 3  GT3462   Ricardo     30  88888-111
# 4  HH1158     Maria     27  77777-666

# %%
# Registros de Compras de Todas Unidades

compras = {'Id': ['AA2930', 'EF4488', 'CC2139', 'EF4488', 'CC9999', 'AA2930', 'HH1158', 'HH1158'],
        "Data": ['2019-01-01', '2019-01-30', '2019-02-01', '2019-02-20', 
        '2019-03-15', '2019-04-25', '2019-04-30', '2019-05-22'],
        'Valor': [200, 100, 45, 150, 300, 35, 50, 450]}

compras = pd.DataFrame(compras, columns=['Id', 'Data', 'Valor'])
compras
# Out:
#        Id        Data  Valor
# 0  AA2930  2019-01-01    200
# 1  EF4488  2019-01-30    100
# 2  CC2139  2019-02-01     45
# 3  EF4488  2019-02-20    150
# 4  CC9999  2019-03-15    300
# 5  AA2930  2019-04-25     35
# 6  HH1158  2019-04-30     50
# 7  HH1158  2019-05-22    450

# %%
# Interseção da loja-a e loja-b
from IPython.display import Image
Image("dados/img.png")

# %% [markdown]
# ## Inner Join

# %%
# Interseção de Id, Idade e CEP
pd.merge(cadastro_a, cadastro_b, on=['Id'], how='inner')
# Out:
#        Id   Nome_x  Idade_x      CEP_x   Nome_y  Idade_y      CEP_y
# 0  GT3462  Ricardo       30  88888-111  Ricardo       30  88888-111
# 1  HH1158    Maria       27  77777-666    Maria       27  77777-666

# %%
pd.merge(cadastro_a, cadastro_b[['Id', 'Idade', 'CEP']], on=['Id'], how='inner')
# Out:
#        Id     Nome  Idade_x      CEP_x  Idade_y      CEP_y
# 0  GT3462  Ricardo       30  88888-111       30  88888-111
# 1  HH1158    Maria       27  77777-666       27  77777-666

# %%
# Mudança do Sufixo
pd.merge(cadastro_a, cadastro_b[['Id','Idade','CEP']], on=['Id'], how='inner', suffixes=('_A', '_B'))
# Out:
#        Id     Nome  Idade_A      CEP_A  Idade_B      CEP_B
# 0  GT3462  Ricardo       30  88888-111       30  88888-111
# 1  HH1158    Maria       27  77777-666       27  77777-666

# %% [markdown]
# ## Full Join

# %%
lojas = pd.concat([cadastro_a, cadastro_b], ignore_index=True)
lojas
# Out:
#         Id      Nome  Idade        CEP
# 0   AA2930    Victor     20  00092-029
# 1   BB4563    Amanda     35  11111-111
# 2   CC2139     Bruna     40  00000-999
# 3   DE2521    Carlos     54  22222-888
# 4   GT3462   Ricardo     30  88888-111
# 5   HH1158     Maria     27  77777-666
# 6   CC9999    Marcos     19  00092-029
# 7   EF4488  Patricia     30  11111-111
# 8   DD9999    Ericka     22  11111-888
# 9   GT3462   Ricardo     30  88888-111
# 10  HH1158     Maria     27  77777-666

# %%
# Removendo Dados Duplicados
# subset = Mostrarei por onde quero remover
clientes_unicos = lojas.drop_duplicates(subset='Id')
clientes_unicos
# Out:
#        Id      Nome  Idade        CEP
# 0  AA2930    Victor     20  00092-029
# 1  BB4563    Amanda     35  11111-111
# 2  CC2139     Bruna     40  00000-999
# 3  DE2521    Carlos     54  22222-888
# 4  GT3462   Ricardo     30  88888-111
# 5  HH1158     Maria     27  77777-666
# 6  CC9999    Marcos     19  00092-029
# 7  EF4488  Patricia     30  11111-111
# 8  DD9999    Ericka     22  11111-888

# %% [markdown]
# ## Left Join

# %%
esquerda = pd.merge(cadastro_a, compras, how='left', on=['Id'])
esquerda
# Out:
#        Id     Nome  Idade        CEP        Data  Valor
# 0  AA2930   Victor     20  00092-029  2019-01-01  200.0
# 1  AA2930   Victor     20  00092-029  2019-04-25   35.0
# 2  BB4563   Amanda     35  11111-111         NaN    NaN
# 3  CC2139    Bruna     40  00000-999  2019-02-01   45.0
# 4  DE2521   Carlos     54  22222-888         NaN    NaN
# 5  GT3462  Ricardo     30  88888-111         NaN    NaN
# 6  HH1158    Maria     27  77777-666  2019-04-30   50.0
# 7  HH1158    Maria     27  77777-666  2019-05-22  450.0

# %% [markdown]
# ## Usando o GroupBy

# %%
esquerda.groupby(['Id', 'Nome'])['Valor'].sum()
# Out:
# Id      Nome
# AA2930  Victor     235.0
# BB4563  Amanda       0.0
# CC2139  Bruna       45.0
# DE2521  Carlos       0.0
# GT3462  Ricardo      0.0
# HH1158  Maria      500.0
# Name: Valor, dtype: float64

# %% [markdown]
# ## Outer Join

# %%
pd.merge(cadastro_a, cadastro_b, how='outer', on=['Id'], indicator=True)
# Out:
#        Id   Nome_x  Idade_x      CEP_x    Nome_y  Idade_y      CEP_y  \
# 0  AA2930   Victor     20.0  00092-029       NaN      NaN        NaN
# 1  BB4563   Amanda     35.0  11111-111       NaN      NaN        NaN
# 2  CC2139    Bruna     40.0  00000-999       NaN      NaN        NaN
# 3  DE2521   Carlos     54.0  22222-888       NaN      NaN        NaN
# 4  GT3462  Ricardo     30.0  88888-111   Ricardo     30.0  88888-111
# 5  HH1158    Maria     27.0  77777-666     Maria     27.0  77777-666
# 6  CC9999      NaN      NaN        NaN    Marcos     19.0  00092-029
# 7  EF4488      NaN      NaN        NaN  Patricia     30.0  11111-111
# 8  DD9999      NaN      NaN        NaN    Ericka     22.0  11111-888
#
#        _merge
# 0   left_only
# 1   left_only
# 2   left_only
# 3   left_only
# 4        both
# 5        both
# 6  right_only
# 7  right_only
# 8  right_only

# %%
# Usando o GroupBy
# GroupBy - Agrupa por

df = pd.DataFrame({'A': ['verdadeiro', 'falso', 'verdadeiro', 'falso',
                        'verdadeiro', 'falso', 'verdadeiro', 'falso'],
                  'B': ['um', 'um', 'dois', 'tres', 'dois', 'dois', 'um', 'tres'],
                  'C': np.random.randn(8),
                  'D': np.random.randn(8)})
df
# Out:
#             A     B         C         D
# 0  verdadeiro    um  1.839803 -0.743916
# 1       falso    um  1.435152  0.642613
# 2  verdadeiro  dois -0.239727 -0.084264
# 3       falso  tres -0.613684  0.617469
# 4  verdadeiro  dois -1.752348 -0.274798
# 5       falso  dois  0.614308  1.313131
# 6  verdadeiro    um -0.617859  0.331179
# 7       falso  tres  0.003679 -0.876306

# %%
# Agrupando pela soma da coluna A
df.groupby(['A']).sum()
# Out:
#                    C         D
# A
# falso       1.439455  1.696907
# verdadeiro -0.770130 -0.771799

# %%
# Agrupando pela soma da coluna B
df.groupby(['B']).sum()
# Out:
#              C         D
# B
# dois -1.377767  0.954069
# tres -0.610005 -0.258837
# um    2.657096  0.229876

# %%
# Agrupando Pela soma das colunas A e B

df.groupby(['A', 'B']).sum()
# Out:
#                         C         D
# A          B
# falso      dois  0.614308  1.313131
#            tres -0.610005 -0.258837
#            um    1.435152  0.642613
# verdadeiro dois -1.992075 -0.359062
#            um    1.221944 -0.412737

# %% [markdown]
# ### Rehaping de Dados - Reformula/Reorganiza os Dados

# %%
# Criando dados
datas = pd.date_range('20190101', periods=6)
df = pd.DataFrame(np.random.randn(6,4), index=datas, columns=['Var_A', 'Var_B', 'Var_C', 'Var_D'])
df
# Out:
#                Var_A     Var_B     Var_C     Var_D
# 2019-01-01  1.691162  1.969305 -0.781448 -1.873900
# 2019-01-02 -1.579286  0.648362  0.737972  1.817688
# 2019-01-03  2.119961 -1.165948 -0.561065 -0.036245
# 2019-01-04  0.062398 -0.139040 -1.680072 -0.486946
# 2019-01-05  1.911118 -0.748049 -1.217464 -0.490270
# 2019-01-06  0.299319 -1.192908  0.642779 -1.193875

# %%
# Transposta dos Dados
dft = df.T
dft
# Out:
#        2019-01-01  2019-01-02  2019-01-03  2019-01-04  2019-01-05  2019-01-06
# Var_A    1.691162   -1.579286    2.119961    0.062398    1.911118    0.299319
# Var_B    1.969305    0.648362   -1.165948   -0.139040   -0.748049   -1.192908
# Var_C   -0.781448    0.737972   -0.561065   -1.680072   -1.217464    0.642779
# Var_D   -1.873900    1.817688   -0.036245   -0.486946   -0.490270   -1.193875

# %%
# Dimensões dos Dados
df.shape, dft.shape
# Out:
# ((6, 4), (4, 6))

# %%
# Extraindo apenas os dados numericos, valores
df.values
# Out:
# array([[ 1.69116227,  1.96930542, -0.78144781, -1.87389981],
#        [-1.57928612,  0.64836151,  0.73797157,  1.81768767],
#        [ 2.11996061, -1.16594777, -0.56106513, -0.03624474],
#        [ 0.06239839, -0.13904012, -1.68007209, -0.48694556],
#        [ 1.91111817, -0.74804947, -1.21746353, -0.49027003],
#        [ 0.29931885, -1.19290752,  0.64277888, -1.19387454]])

# %%
# Extraindo os Valores
dft.values
# Out:
# array([[ 1.69116227, -1.57928612,  2.11996061,  0.06239839,  1.91111817,
#          0.29931885],
#        [ 1.96930542,  0.64836151, -1.16594777, -0.13904012, -0.74804947,
#         -1.19290752],
#        [-0.78144781,  0.73797157, -0.56106513, -1.68007209, -1.21746353,
#          0.64277888],
#        [-1.87389981,  1.81768767, -0.03624474, -0.48694556, -0.49027003,
#         -1.19387454]])

# %%
# Reshape dos Dados
v = dft.values
v.reshape((2, 12))
# Out:
# array([[ 1.69116227, -1.57928612,  2.11996061,  0.06239839,  1.91111817,
#          0.29931885,  1.96930542,  0.64836151, -1.16594777, -0.13904012,
#         -0.74804947, -1.19290752],
#        [-0.78144781,  0.73797157, -0.56106513, -1.68007209, -1.21746353,
#          0.64277888, -1.87389981,  1.81768767, -0.03624474, -0.48694556,
#         -0.49027003, -1.19387454]])

# %%
# Função Pivot
dias = pd.date_range(start='20220101', periods=12)
dias
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10', '2022-01-11', '2022-01-12'],
#               dtype='datetime64[ns]', freq='D')

# %%
# Criando lista
pessoa = ['George', 'Victor', 'Lucas']
pessoa
# Out:
# ['George', 'Victor', 'Lucas']

# %%
# Escolha Aleatorios
np.random.choice(pessoa)
# Out:
# 'Victor'

# %%
nome = []
gasto = []
for i in range(12):
    nome.append(np.random.choice(pessoa))
    gasto.append(np.round(np.random.rand()*150))
nome
# Out:
# ['George',
#  'George',
#  'George',
#  'Victor',
#  'Victor',
#  'Victor',
#  'Victor',
#  'Lucas',
#  'Lucas',
#  'Victor',
#  'Lucas',
#  'Victor']

# %%
gasto
# Out:
# [110.0, 100.0, 90.0, 53.0, 76.0, 49.0, 95.0, 102.0, 124.0, 130.0, 80.0, 6.0]

# %%
# Criando o DataFrame
df = pd.DataFrame({'Dia': dias, 
                   'Nome': nome, 
                   'Gasto': gasto})
df
# Out:
#           Dia    Nome  Gasto
# 0  2022-01-01  George  110.0
# 1  2022-01-02  George  100.0
# 2  2022-01-03  George   90.0
# 3  2022-01-04  Victor   53.0
# 4  2022-01-05  Victor   76.0
# 5  2022-01-06  Victor   49.0
# 6  2022-01-07  Victor   95.0
# 7  2022-01-08   Lucas  102.0
# 8  2022-01-09   Lucas  124.0
# 9  2022-01-10  Victor  130.0
# 10 2022-01-11   Lucas   80.0
# 11 2022-01-12  Victor    6.0

# %%
# Função Pivot
df.pivot(index='Dia', columns='Nome', values='Gasto')
# Out:
# Nome        George  Lucas  Victor
# Dia
# 2022-01-01   110.0    NaN     NaN
# 2022-01-02   100.0    NaN     NaN
# 2022-01-03    90.0    NaN     NaN
# 2022-01-04     NaN    NaN    53.0
# 2022-01-05     NaN    NaN    76.0
# 2022-01-06     NaN    NaN    49.0
# 2022-01-07     NaN    NaN    95.0
# 2022-01-08     NaN  102.0     NaN
# 2022-01-09     NaN  124.0     NaN
# 2022-01-10     NaN    NaN   130.0
# 2022-01-11     NaN   80.0     NaN
# 2022-01-12     NaN    NaN     6.0

# %%
# Função Pivot_table
carros = [7, 4, 3, 2, 8]
dias = pd.date_range('20190101', '20190101', periods=5)
vendedor = ['George', 'Vagner', 'Pedro', 'Vagner', 'George']
df = pd.DataFrame({'Vendas':carros, 'Data':dias, 'Vendedor':vendedor})
df
# Out:
#    Vendas       Data Vendedor
# 0       7 2019-01-01   George
# 1       4 2019-01-01   Vagner
# 2       3 2019-01-01    Pedro
# 3       2 2019-01-01   Vagner
# 4       8 2019-01-01   George

# %%
# Usando Pivot
'''pd.pivot(df,index='Data', columns='Vendedor', values='Vendas')
'''
# Ao Usa o Pivot dara erro, pois o index possui valores duplicados
# Out:
# "pd.pivot(df,index='Data', columns='Vendedor', values='Vendas')\n"

# %%
# Usando Pivot_table
pd.pivot_table(df, index='Data', columns='Vendedor', values='Vendas')
# Out:
# Vendedor    George  Pedro  Vagner
# Data
# 2019-01-01     7.5    3.0     3.0

# %%
# Stack e Unstack
df = pd.read_csv('dados/nba.csv')
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
# Usando o stack
stack_df = df.stack()
stack_df
# Out:
# 0    Name         Avery Bradley
#      Team        Boston Celtics
#      Number                 0.0
#      Position                PG
#      Age                   25.0
#                       ...
# 456  Age                   26.0
#      Height                 7-0
#      Weight               231.0
#      College             Kansas
#      Salary            947276.0
# Length: 4018, dtype: object

# %%
# Usando o Unstack, para retorna a forma padrao dos dados
udf = stack_df.unstack()
udf.head()
# Out:
#             Name            Team Number Position   Age Height Weight  \
# 0  Avery Bradley  Boston Celtics    0.0       PG  25.0    6-2  180.0
# 1    Jae Crowder  Boston Celtics   99.0       SF  25.0    6-6  235.0
# 2   John Holland  Boston Celtics   30.0       SG  27.0    6-5  205.0
# 3    R.J. Hunter  Boston Celtics   28.0       SG  22.0    6-5  185.0
# 4  Jonas Jerebko  Boston Celtics    8.0       PF  29.0   6-10  231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
# Usando o Melt
df = pd.DataFrame({'A': {0: 'a', 1:'b', 2:'c'},
                  'B': {0:1, 1:3, 2:5},
                  'C': {0:2, 1:4, 2:6}})
df
# Out:
#    A  B  C
# 0  a  1  2
# 1  b  3  4
# 2  c  5  6

# %%
pd.melt(df, id_vars=['A'], value_vars=['B'])
# Out:
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5

# %%
pd.melt(df, id_vars=['A'], value_vars=['B', 'C'])
# Out:
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5
# 3  a        C      2
# 4  b        C      4
# 5  c        C      6

# %% [markdown]
# ### Filtros e Manipulações de Dados

# %%
# Criando os Dados
datas = pd.date_range('20180101', periods=600, freq='D')
df = pd.DataFrame(np.random.randn(600,5), index=datas, columns=list('ABCDE'))
df
# Out:
#                    A         B         C         D         E
# 2018-01-01  1.624978  0.724045  1.190629 -1.334479  0.942303
# 2018-01-02 -0.873062  0.101457 -0.380457 -0.443003 -1.001557
# 2018-01-03 -0.598126  0.845983 -1.829594  0.252923  1.644594
# 2018-01-04 -0.513138 -1.146112 -1.106955 -0.704451 -0.527623
# 2018-01-05 -0.030185  0.916283 -1.856397  0.393578  0.512368
# ...              ...       ...       ...       ...       ...
# 2019-08-19  1.165862  2.088616 -0.442199  0.945031 -1.887762
# 2019-08-20 -1.590171 -1.814661 -0.545960  0.762440 -0.147122
# 2019-08-21 -0.039662 -1.194460  1.005492 -1.384622  1.902335
# 2019-08-22 -0.907760  0.143028 -2.690121 -0.100795 -0.673868
# 2019-08-23  1.301817  1.316844  0.066414 -0.322136  0.941270
#
# [600 rows x 5 columns]

# %%
# Obtendo dados de determinada coluna
df['D'] # Dessa forma retornaram como dataseries
# Out:
# 2018-01-01   -1.334479
# 2018-01-02   -0.443003
# 2018-01-03    0.252923
# 2018-01-04   -0.704451
# 2018-01-05    0.393578
#                 ...
# 2019-08-19    0.945031
# 2019-08-20    0.762440
# 2019-08-21   -1.384622
# 2019-08-22   -0.100795
# 2019-08-23   -0.322136
# Freq: D, Name: D, Length: 600, dtype: float64

# %%
# Obtendo dados de determinada coluna
df[['D']] # Dessa forma retornaram como DataFrame
# Out:
#                    D
# 2018-01-01 -1.334479
# 2018-01-02 -0.443003
# 2018-01-03  0.252923
# 2018-01-04 -0.704451
# 2018-01-05  0.393578
# ...              ...
# 2019-08-19  0.945031
# 2019-08-20  0.762440
# 2019-08-21 -1.384622
# 2019-08-22 -0.100795
# 2019-08-23 -0.322136
#
# [600 rows x 1 columns]

# %%
# Usando o loc
df.loc[:, ['A', 'B']]
# Out:
#                    A         B
# 2018-01-01  1.624978  0.724045
# 2018-01-02 -0.873062  0.101457
# 2018-01-03 -0.598126  0.845983
# 2018-01-04 -0.513138 -1.146112
# 2018-01-05 -0.030185  0.916283
# ...              ...       ...
# 2019-08-19  1.165862  2.088616
# 2019-08-20 -1.590171 -1.814661
# 2019-08-21 -0.039662 -1.194460
# 2019-08-22 -0.907760  0.143028
# 2019-08-23  1.301817  1.316844
#
# [600 rows x 2 columns]

# %%
# Usando o iloc
df.iloc[1:, 0:3]
# Out:
#                    A         B         C
# 2018-01-02 -0.873062  0.101457 -0.380457
# 2018-01-03 -0.598126  0.845983 -1.829594
# 2018-01-04 -0.513138 -1.146112 -1.106955
# 2018-01-05 -0.030185  0.916283 -1.856397
# 2018-01-06  0.258329 -1.578788 -0.828383
# ...              ...       ...       ...
# 2019-08-19  1.165862  2.088616 -0.442199
# 2019-08-20 -1.590171 -1.814661 -0.545960
# 2019-08-21 -0.039662 -1.194460  1.005492
# 2019-08-22 -0.907760  0.143028 -2.690121
# 2019-08-23  1.301817  1.316844  0.066414
#
# [599 rows x 3 columns]

# %%
# Usando o Iloc
# Primeiro linha depois coluna
df.iloc[1:, 0:3]
# Out:
#                    A         B         C
# 2018-01-02 -0.873062  0.101457 -0.380457
# 2018-01-03 -0.598126  0.845983 -1.829594
# 2018-01-04 -0.513138 -1.146112 -1.106955
# 2018-01-05 -0.030185  0.916283 -1.856397
# 2018-01-06  0.258329 -1.578788 -0.828383
# ...              ...       ...       ...
# 2019-08-19  1.165862  2.088616 -0.442199
# 2019-08-20 -1.590171 -1.814661 -0.545960
# 2019-08-21 -0.039662 -1.194460  1.005492
# 2019-08-22 -0.907760  0.143028 -2.690121
# 2019-08-23  1.301817  1.316844  0.066414
#
# [599 rows x 3 columns]

# %%
# Usando o Iloc
# Primeiro linha depois coluna
df.iloc[[1, 5, 6], [0, 3]]
# Out:
#                    A         D
# 2018-01-02 -0.873062 -0.443003
# 2018-01-06  0.258329 -1.289024
# 2018-01-07  0.488089  0.536655

# %%
# Usando o Iloc
# Primeiro linha depois coluna
df.head()
# Out:
#                    A         B         C         D         E
# 2018-01-01  1.624978  0.724045  1.190629 -1.334479  0.942303
# 2018-01-02 -0.873062  0.101457 -0.380457 -0.443003 -1.001557
# 2018-01-03 -0.598126  0.845983 -1.829594  0.252923  1.644594
# 2018-01-04 -0.513138 -1.146112 -1.106955 -0.704451 -0.527623
# 2018-01-05 -0.030185  0.916283 -1.856397  0.393578  0.512368

# %%
# Selecionando valores mairoes que 0
df[df.A > 0].head()
# Out:
#                    A         B         C         D         E
# 2018-01-01  1.624978  0.724045  1.190629 -1.334479  0.942303
# 2018-01-06  0.258329 -1.578788 -0.828383 -1.289024  0.035514
# 2018-01-07  0.488089 -0.432024 -1.246013  0.536655 -0.051204
# 2018-01-08  1.634989  0.727418  0.145619  1.609201 -0.563976
# 2018-01-10  0.396848  0.505229 -1.120813  0.011101 -0.361489

# %% [markdown]
# ### Limpeza e Estruturação dos Dados

# %%
# Criando um Novo DataFrame
datas = pd.date_range('20200101', periods=6)
df = pd.DataFrame(np.random.randn(6, 4), index=datas, columns=['Var_A', 'Var_B', 'Var_C', 'Var_D'])
df
# Out:
#                Var_A     Var_B     Var_C     Var_D
# 2020-01-01  2.477989  0.192616 -0.387306  2.673065
# 2020-01-02 -0.924633  2.273804  0.138502  0.332003
# 2020-01-03  1.199137  0.426955  0.953640 -0.174006
# 2020-01-04 -2.191141  1.091772  1.626955  0.902181
# 2020-01-05  0.057184  2.136999  1.709014 -0.410009
# 2020-01-06  0.154651  1.133903  2.039390  0.164832

# %%
df2 = pd.DataFrame({"A": 1, 
                    "B": pd.Timestamp('20130102'),
                    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                    "D": np.array([3] * 4, dtype='int32'),
                    'E': pd.Categorical(['test', 'train', 'test', 'train']),
                    'F': 'Python'})
df2
# Out:
#    A          B    C  D      E       F
# 0  1 2013-01-02  1.0  3   test  Python
# 1  1 2013-01-02  1.0  3  train  Python
# 2  1 2013-01-02  1.0  3   test  Python
# 3  1 2013-01-02  1.0  3  train  Python

# %%
df.shape, df2.shape
# Out:
# ((6, 4), (4, 6))

# %%
df.dtypes, df2.dtypes
# Out:
# (Var_A    float64
#  Var_B    float64
#  Var_C    float64
#  Var_D    float64
#  dtype: object,
#  A             int64
#  B    datetime64[ns]
#  C           float32
#  D             int32
#  E          category
#  F            object
#  dtype: object)

# %%
# Descrição dos Dados
df.describe()
# Out:
#           Var_A     Var_B     Var_C     Var_D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.128864  1.209341  1.013366  0.581344
# std    1.622464  0.855453  0.963741  1.119573
# min   -2.191141  0.192616 -0.387306 -0.410009
# 25%   -0.679179  0.593159  0.342287 -0.089297
# 50%    0.105918  1.112838  1.290298  0.248418
# 75%    0.938015  1.886225  1.688499  0.759637
# max    2.477989  2.273804  2.039390  2.673065

# %%
# Criando um novo dataframe a partir do primeiro

df1 = df.reindex(index=datas[0:4], columns=list(df.columns) + ['Var_E'])
df1
# Out:
#                Var_A     Var_B     Var_C     Var_D  Var_E
# 2020-01-01  2.477989  0.192616 -0.387306  2.673065    NaN
# 2020-01-02 -0.924633  2.273804  0.138502  0.332003    NaN
# 2020-01-03  1.199137  0.426955  0.953640 -0.174006    NaN
# 2020-01-04 -2.191141  1.091772  1.626955  0.902181    NaN

# %%
# Adicionando Valores a coluna Var_E

df1.loc[datas[0]:datas[1], 'Var_E'] = 1
df1
# Out:
#                Var_A     Var_B     Var_C     Var_D  Var_E
# 2020-01-01  2.477989  0.192616 -0.387306  2.673065    1.0
# 2020-01-02 -0.924633  2.273804  0.138502  0.332003    1.0
# 2020-01-03  1.199137  0.426955  0.953640 -0.174006    NaN
# 2020-01-04 -2.191141  1.091772  1.626955  0.902181    NaN

# %%
df.dtypes
# Out:
# Var_A    float64
# Var_B    float64
# Var_C    float64
# Var_D    float64
# dtype: object

# %%
df1.describe()
# Out:
#           Var_A     Var_B     Var_C     Var_D  Var_E
# count  4.000000  4.000000  4.000000  4.000000    2.0
# mean   0.140338  0.996287  0.582948  0.933311    1.0
# std    2.094089  0.932951  0.888123  1.240354    0.0
# min   -2.191141  0.192616 -0.387306 -0.174006    1.0
# 25%   -1.241260  0.368370  0.007050  0.205501    1.0
# 50%    0.137252  0.759363  0.546071  0.617092    1.0
# 75%    1.518850  1.387280  1.121969  1.344902    1.0
# max    2.477989  2.273804  1.626955  2.673065    1.0

# %%
# Dados Faltantes 
# Criando um novo DataFrame
datas = pd.date_range('20190101', periods=60, freq='D')
df = pd.DataFrame(np.random.randn(60, 10), index=datas, columns=list('ABCDEFGHIJ'))
df.head()
# Out:
#                    A         B         C         D         E         F  \
# 2019-01-01 -0.571789  1.121118  1.190660  0.766162  0.538531 -0.098635
# 2019-01-02  0.498049  0.274762 -0.913402 -1.180316 -1.087019 -1.569424
# 2019-01-03 -0.399603  0.600355  0.232152  0.642146  0.048050  1.414592
# 2019-01-04 -1.259839  1.347365 -1.027678  0.120735 -0.983928 -0.947399
# 2019-01-05 -1.441529  0.111185 -0.135217 -0.834459  0.550854  0.261233
#
#                    G         H         I         J
# 2019-01-01  0.087576 -0.167830 -0.670892 -0.406858
# 2019-01-02  0.724474 -1.108530  1.129271 -1.754092
# 2019-01-03 -0.503470  0.242116  0.496091  0.625977
# 2019-01-04  0.108148 -0.901740  2.114306  0.920247
# 2019-01-05  0.625913 -0.067984  0.527436 -0.572603

# %%
# Gerando uma logica com valores NaN
df['F'] = df.F[df.F > 0]
df['G'] = df.G[df.G > 0]
df['J'] = df.J[df.J > 0]
df.head()
# Out:
#                    A         B         C         D         E         F  \
# 2019-01-01 -0.571789  1.121118  1.190660  0.766162  0.538531       NaN
# 2019-01-02  0.498049  0.274762 -0.913402 -1.180316 -1.087019       NaN
# 2019-01-03 -0.399603  0.600355  0.232152  0.642146  0.048050  1.414592
# 2019-01-04 -1.259839  1.347365 -1.027678  0.120735 -0.983928       NaN
# 2019-01-05 -1.441529  0.111185 -0.135217 -0.834459  0.550854  0.261233
#
#                    G         H         I         J
# 2019-01-01  0.087576 -0.167830 -0.670892       NaN
# 2019-01-02  0.724474 -1.108530  1.129271       NaN
# 2019-01-03       NaN  0.242116  0.496091  0.625977
# 2019-01-04  0.108148 -0.901740  2.114306  0.920247
# 2019-01-05  0.625913 -0.067984  0.527436       NaN

# %%
# Visualizando as informações do df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 60 entries, 2019-01-01 to 2019-03-01
# Freq: D
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       60 non-null     float64
#  1   B       60 non-null     float64
#  2   C       60 non-null     float64
#  3   D       60 non-null     float64
#  4   E       60 non-null     float64
#  5   F       31 non-null     float64
#  6   G       31 non-null     float64
#  7   H       60 non-null     float64
#  8   I       60 non-null     float64
#  9   J       28 non-null     float64
# dtypes: float64(10)
# memory usage: 5.2 KB

# %%
# Visualizando Dados Nulos
df.isnull().sum()
# Out:
# A     0
# B     0
# C     0
# D     0
# E     0
# F    29
# G    29
# H     0
# I     0
# J    32
# dtype: int64

# %%
# Criando Copias para manipulação
df2 = df.copy()
df3 = df.copy()

# %%
df2.head()
# Out:
#                    A         B         C         D         E         F  \
# 2019-01-01 -0.571789  1.121118  1.190660  0.766162  0.538531       NaN
# 2019-01-02  0.498049  0.274762 -0.913402 -1.180316 -1.087019       NaN
# 2019-01-03 -0.399603  0.600355  0.232152  0.642146  0.048050  1.414592
# 2019-01-04 -1.259839  1.347365 -1.027678  0.120735 -0.983928       NaN
# 2019-01-05 -1.441529  0.111185 -0.135217 -0.834459  0.550854  0.261233
#
#                    G         H         I         J
# 2019-01-01  0.087576 -0.167830 -0.670892       NaN
# 2019-01-02  0.724474 -1.108530  1.129271       NaN
# 2019-01-03       NaN  0.242116  0.496091  0.625977
# 2019-01-04  0.108148 -0.901740  2.114306  0.920247
# 2019-01-05  0.625913 -0.067984  0.527436       NaN

# %%
df3.head()
# Out:
#                    A         B         C         D         E         F  \
# 2019-01-01 -0.571789  1.121118  1.190660  0.766162  0.538531       NaN
# 2019-01-02  0.498049  0.274762 -0.913402 -1.180316 -1.087019       NaN
# 2019-01-03 -0.399603  0.600355  0.232152  0.642146  0.048050  1.414592
# 2019-01-04 -1.259839  1.347365 -1.027678  0.120735 -0.983928       NaN
# 2019-01-05 -1.441529  0.111185 -0.135217 -0.834459  0.550854  0.261233
#
#                    G         H         I         J
# 2019-01-01  0.087576 -0.167830 -0.670892       NaN
# 2019-01-02  0.724474 -1.108530  1.129271       NaN
# 2019-01-03       NaN  0.242116  0.496091  0.625977
# 2019-01-04  0.108148 -0.901740  2.114306  0.920247
# 2019-01-05  0.625913 -0.067984  0.527436       NaN

# %%
# O Metodo Fillna Preenche os valores faltantes
df2.F.fillna(np.mean(df2.F))
df2.head()
# Out:
#                    A         B         C         D         E         F  \
# 2019-01-01 -0.571789  1.121118  1.190660  0.766162  0.538531       NaN
# 2019-01-02  0.498049  0.274762 -0.913402 -1.180316 -1.087019       NaN
# 2019-01-03 -0.399603  0.600355  0.232152  0.642146  0.048050  1.414592
# 2019-01-04 -1.259839  1.347365 -1.027678  0.120735 -0.983928       NaN
# 2019-01-05 -1.441529  0.111185 -0.135217 -0.834459  0.550854  0.261233
#
#                    G         H         I         J
# 2019-01-01  0.087576 -0.167830 -0.670892       NaN
# 2019-01-02  0.724474 -1.108530  1.129271       NaN
# 2019-01-03       NaN  0.242116  0.496091  0.625977
# 2019-01-04  0.108148 -0.901740  2.114306  0.920247
# 2019-01-05  0.625913 -0.067984  0.527436       NaN

# %%
# Limpeza
df2 = pd.DataFrame({"A": 1, 
                    "B": pd.Timestamp('20130102'),
                    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                    "D": np.array([3] * 4, dtype='int32'),
                    'E': pd.Categorical(['test', 'train', 'test', 'train']),
                    'F': 'Python',
                    'G': [2,2,4,4],
                    'H': [np.nan,2,4,np.nan]})
df2
# Out:
#    A          B    C  D      E       F  G    H
# 0  1 2013-01-02  1.0  3   test  Python  2  NaN
# 1  1 2013-01-02  1.0  3  train  Python  2  2.0
# 2  1 2013-01-02  1.0  3   test  Python  4  4.0
# 3  1 2013-01-02  1.0  3  train  Python  4  NaN

# %%
# Verificando se Existe dados repetidos
df2.nunique()
# Out:
# A    1
# B    1
# C    1
# D    1
# E    2
# F    1
# G    2
# H    2
# dtype: int64

# %%
df2.nunique(axis=1, dropna=False)
df2
# Out:
#    A          B    C  D      E       F  G    H
# 0  1 2013-01-02  1.0  3   test  Python  2  NaN
# 1  1 2013-01-02  1.0  3  train  Python  2  2.0
# 2  1 2013-01-02  1.0  3   test  Python  4  4.0
# 3  1 2013-01-02  1.0  3  train  Python  4  NaN

# %%
# Removera os dados duplicados
df2.drop_duplicates(subset='G', keep='last')
# Out:
#    A          B    C  D      E       F  G    H
# 1  1 2013-01-02  1.0  3  train  Python  2  2.0
# 3  1 2013-01-02  1.0  3  train  Python  4  NaN

# %%
# Ordenação dos Dados
df.sort_values(by='A', ascending=True).head()
# Out:
#                    A         B         C         D         E         F  \
# 2019-01-19 -2.598614  1.626813 -0.862259 -0.926390 -0.208410  2.656992
# 2019-01-21 -2.144482 -0.849050  0.061140  1.624245  0.997574       NaN
# 2019-02-08 -2.078539  0.267964  0.570313  0.236569  0.225506  0.873029
# 2019-01-29 -2.051389 -1.456428  0.330548 -0.752345 -0.169339  0.365820
# 2019-02-06 -1.767501  0.324925  0.446490  1.255309  1.674821       NaN
#
#                    G         H         I         J
# 2019-01-19       NaN -1.132786  0.496565       NaN
# 2019-01-21       NaN -2.081382  0.900064  1.245261
# 2019-02-08  0.735965 -0.758565  1.292974  0.501095
# 2019-01-29       NaN -0.135036 -0.450856  1.031063
# 2019-02-06  1.672039 -1.982612  0.480386       NaN

# %%
# Ordenando da coluna b
df.sort_values(by='B', ascending=False).head()
# Out:
#                    A         B         C         D         E         F  \
# 2019-02-27  0.907536  1.845998  1.389427 -0.926873 -0.216459  1.532118
# 2019-01-19 -2.598614  1.626813 -0.862259 -0.926390 -0.208410  2.656992
# 2019-01-04 -1.259839  1.347365 -1.027678  0.120735 -0.983928       NaN
# 2019-01-01 -0.571789  1.121118  1.190660  0.766162  0.538531       NaN
# 2019-02-14 -0.261569  1.092485  1.564847  0.222339 -1.855960       NaN
#
#                    G         H         I         J
# 2019-02-27  0.277438 -1.556216 -0.556413       NaN
# 2019-01-19       NaN -1.132786  0.496565       NaN
# 2019-01-04  0.108148 -0.901740  2.114306  0.920247
# 2019-01-01  0.087576 -0.167830 -0.670892       NaN
# 2019-02-14  1.400726  1.930692  0.657283       NaN

# %% [markdown]
# ### Importando e Exportando

# %%
# Importando as Bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
# Importando os Dados
df = pd.read_csv('dados/iris.csv')
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Stilos de Graficos
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# Especificando qual stilo de grafico quero utiliza
plt.style.use('seaborn-paper')

# %%
df = pd.read_csv('dados/train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
plt.plot(df.Age, '-')
